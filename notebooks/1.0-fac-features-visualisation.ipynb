# %%
import os
import sys

# add the 'src' directory as one where we can import modules
src_dir = os.path.join(os.getcwd(), os.pardir, 'src')
sys.path.append(src_dir)

from features.generate_features import *
from visualisation.graphs import *
import pandas as pd
import matplotlib.pyplot as plt
import seaborn

# %matplotlib inline

# %% [markdown]
# # Load feature dataset

# %%
# load features CSV
filepath = os.path.join(os.getcwd(), os.pardir, 'data', 'features.csv')
df = pd.read_csv(filepath, sep=',')

# split data into positive and negative labels
pos_labels = df[df['class'] == 1]
neg_labels = df[df['class'] == 0]

# %%
df.head()
# Out:
#    class  acousticness  danceability  duration_ms  energy  instrumentalness  \
# 0      1      0.000283         0.641       177280   0.889          0.000723
# 1      1      0.096400         0.728       214853   0.673          0.000007
# 2      1      0.000271         0.496       221293   0.803          0.000007
# 3      1      0.008440         0.495       171973   0.839          0.000469
# 4      1      0.000005         0.465       230560   0.847          0.000037
#
#    key  liveness  loudness  mode  speechiness    tempo  time_signature  \
# 0    1    0.2880    -4.302     1       0.0280   99.012               4
# 1    5    0.0695    -5.766     1       0.0318  127.995               4
# 2    5    0.1280    -6.519     1       0.0331  140.538               4
# 3    1    0.0939    -7.800     0       0.0377  158.425               4
# 4   11    0.3830    -6.353     1       0.0444  136.075               4
#
#    valence
# 0    0.738
# 1    0.489
# 2    0.656
# 3    0.742
# 4    0.550

# %% [markdown]
# # Plot data using histograms

# %%
histograms(pos_labels, neg_labels)
